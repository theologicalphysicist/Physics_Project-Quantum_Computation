# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator
from qiskit import (
    QuantumCircuit, 
    Aer, 
    IBMQ, 
    assemble, 
    transpile,
    execute,
)
from qiskit.test.mock import FakeAthens
import math
IBMQ.save_account("5743a5c607636e43b7431c0370ec874af29cbf102ad69bcfc87a0fbbd1cf560fd841e69aef0e96eb0e1b6e3a59c5c3d72d89623b46f0964099e0195708aa9c05")
# Out:
# configrc.store_credentials:WARNING:2022-03-13 06:58:33,819: Credentials already present. Set overwrite=True to overwrite.

# %%
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.measure_all()
circuit.draw(output="mpl")

# %%
IBMQ.load_account()
# simulator = Aer.get_backend("qasm_simulator")
# job_sim = simulator.run(transpile(circuit, simulator), shots=4000)

# counts = job_sim.result().get_counts(circuit)
# plot_histogram(counts)

provider = IBMQ.get_provider(hub="ibm-q")
device = provider.get_backend("ibmq_armonk")

counts = execute(circuit, device).result().get_counts()
plot_histogram(counts)
# Out:
# ibmqfactory.load_account:WARNING:2022-03-13 07:23:40,642: Credentials are already in use. The existing account in the session will be replaced.
