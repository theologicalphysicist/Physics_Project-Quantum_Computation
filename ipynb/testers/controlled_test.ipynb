# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator
from qiskit import (
    QuantumCircuit,  
    IBMQ, 
    assemble, 
    transpile,
    execute,
    Aer,
)
from qiskit.test.mock import FakeAthens
import math

IBMQ.save_account("5743a5c607636e43b7431c0370ec874af29cbf102ad69bcfc87a0fbbd1cf560fd841e69aef0e96eb0e1b6e3a59c5c3d72d89623b46f0964099e0195708aa9c05")

# %%
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cx(0, 2)
circuit.measure_all()
circuit.draw(output="mpl")

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
device = provider.get_backend("ibmq_belem")

counts = execute(circuit, device).result().get_counts()
plot_histogram(counts)

# %%
entanglement_circuit = QuantumCircuit(3)
entanglement_circuit.h(0)
entanglement_circuit.cx(0, 2)
entanglement_circuit.x(0)
entanglement_circuit.measure_all()
entanglement_circuit.draw(output="mpl")

# %%
provider = IBMQ.get_provider(hub='ibm-q')
device = provider.get_backend("ibmq_quito")

counts = execute(entanglement_circuit, device).result().get_counts()
plot_histogram(counts)
